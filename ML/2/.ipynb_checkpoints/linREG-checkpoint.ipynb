# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('maison_prix_tabulaire.csv')

df.head()
# Out:
#    surface_m2  rooms  age_years  price_keuro
# 0      143.83      4       34.1       367.03
# 1       90.22      2       27.8       256.99
# 2      157.38      4       31.4       410.29
# 3      131.58      4       16.5       325.75
# 4       35.07      1       22.8       125.78

# %% [markdown]
# ## 1. Exploration des données
# Statistiques descriptives (`describe`), vérifier les types, les valeurs manquantes.

# %% [markdown]
# ## 2. Visualisation
# Matrice de corrélation (heatmap), scatter plots des features vs target (`price_keuro`).

# %% [markdown]
# ## 3. Séparation features / target
# Définir `X` (surface_m2, rooms, age_years) et `y` (price_keuro).

# %% [markdown]
# ## 4. Split train / test
# `train_test_split` avec un ratio 80/20 et un `random_state` fixé.

# %% [markdown]
# ## 5. Entraînement du modèle
# Instancier et fit un `LinearRegression` de scikit-learn.

# %% [markdown]
# ## 6. Coefficients du modèle
# Afficher les coefficients (`coef_`) et l'intercept (`intercept_`) pour interpréter le modèle.

# %% [markdown]
# ## 7. Prédictions
# Générer `y_pred` sur le jeu de test.

# %% [markdown]
# ## 8. Évaluation
# Calculer MAE, MSE, RMSE et R² (`mean_absolute_error`, `mean_squared_error`, `r2_score`).

# %% [markdown]
# ## 9. Visualisation des résultats
# Scatter plot `y_test` vs `y_pred` avec la droite idéale (y=x) et/ou plot des résidus.
